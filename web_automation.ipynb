# %% [markdown]
# ![web_automation.png](attachment:7b1f3f83-acfd-498c-882e-11586aadbfec.png)

# %% [markdown]
# ## Web Automation
# #### Collaboratively by Joe Eberle , Leslie M. Pfalzer, Sarah Mcinerny started on 02/02/2024

# %%
first_install = False
if first_install:
    # !pip install selenium
    # !pip install webdriver-manager

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
import time
from webdriver_manager.chrome import ChromeDriverManager  
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys

# %% [markdown]
# ## https://sites.google.com/chromium.org/driver/

# %%
service = Service(executable_path="chromedriver.exe")
driver = webdriver.Chrome(service=service) 
driver.get("https://google.com") 
time.sleep(10)
driver.quit()

# %%
service = Service(executable_path="chromedriver.exe")
driver = webdriver.Chrome(service=service) 
driver.get("https://google.com") 

input_element =driver.find_element(By.CLASS_NAME,"gLFyf")
input_element.send_keys("Acute Myocardial Infarction" + Keys.ENTER) 

time.sleep(5)
driver.quit() 
# iNSPECT html TO GET CLASS = gLFyf

# %%
driver = webdriver.Chrome(service=service)
driver.get("https://pubmed.ncbi.nlm.nih.gov/") 

time.sleep(10)
driver.quit()

# %%
driver = webdriver.Chrome(service=service)
driver.get("https://neuralnine.com") 
time.sleep(10)
driver.quit()

# %%
from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.chrome.options import Options # choose your browser 

options = Options()
options.add_experimental_option("detach", True)

driver = webdriver.Chrome(service=service)
driver.get("https://neuralnine.com") 
time.sleep(10)
driver.quit()

# %% [markdown]
# ## Optional Step 0 - Intitiate Configuration Settings and name the overall solution

# %%
import configparser 
config = configparser.ConfigParser()
cfg = config.read('config.ini')  

solution_name = 'web_automation'

# %% [markdown]
# ## Optional Step 0 - Initiate logging

# %%
# Establish the Python Logger  
import logging # built in python library that does not need to be installed 
import quick_logger as ql

global start_stime 
start_time = ql.set_start_time()
logging = ql.create_logger_Start(solution_name, start_time)

# %%
import talking_code as tc  
definition = '''
Selenium is an open-source framework commonly used for automating web applications. 
It provides a suite of tools for web browser automation, allowing developers to interact with 
and control web browsers programmatically. It is Free to use. 
''' 
talking_code = True
if talking_code:
    tc.say(definition)
    print(definition)       
else:
    print(definition)
# Out:
# Selenium is an open-source framework commonly used for automating web applications.
# It provides a suite of tools for web browser automation, allowing developers to interact with
# and control web browsers programmatically. It is Free to use.

# %%
import talking_code as tc  
definition = '''
Web automation using Selenium provides immense value by streamlining repetitive tasks and saving time for users.
It enables the automation of complex workflows, ensuring consistent and error-free execution of tasks, 
ultimately enhancing productivity and efficiency in web development, testing, and data extraction processes.
''' 
talking_code = True
if talking_code:
    tc.say(definition)
    print(definition)       
else:
    print(definition)
# Out:
# Web automation using Selenium provides immense value by streamlining repetitive tasks and saving time for users.
# It enables the automation of complex workflows, ensuring consistent and error-free execution of tasks,
# ultimately enhancing productivity and efficiency in web development, testing, and data extraction processes.

# %%
import talking_code as tc  
definition = '''
 both Chrome and Microsoft Edge browsers are compatible with ChromeDriver. 
 Since Microsoft Edge moved to the Chromium engine, it uses the same WebDriver protocol as Chrome.
 Therefore, you can use ChromeDriver for both Google Chrome and Chromium-based Microsoft Edge browser automation. 
 This makes it convenient for developers and testers as they can use a single driver for automation tasks on both browsers.
''' 
talking_code = True
if talking_code:
    tc.say(definition)
    print(definition)       
else:
    print(definition)
# Out:
#  both Chrome and Microsoft Edge browsers are compatible with ChromeDriver.
#  Since Microsoft Edge moved to the Chromium engine, it uses the same WebDriver protocol as Chrome.
#  Therefore, you can use ChromeDriver for both Google Chrome and Chromium-based Microsoft Edge browser automation.
#  This makes it convenient for developers and testers as they can use a single driver for automation tasks on both browsers.

# %%
def show_time(): 
    import datetime
    current_time = datetime.datetime.now()
    show_time = f'year:{current_time.year}' + f' month:{current_time.month}' + f' day:{current_time.day}'
    show_time = show_time + f' hour:{current_time.hour}' + f' minute:{current_time.minute}' + f' second:{current_time.second}' 
    show_time = show_time + f' microsecond:{current_time.microsecond}' 
    print(show_time)
    return(show_time)

# %%
import talking_code as tc  
definition = '''
web automation tasks completed
''' 
talking_code = True
if talking_code:
    tc.say(definition)
    print(definition)       
else:
    print(definition)
# Out:
# web automation tasks completed

# %%
# Calculate and classify the process performance 
status = ql.calculate_process_performance(solution_name, start_time) 
print(ql.append_log_file(solution_name))
# Out:
# 2024-02-16 16:07:02,762 - INFO - START web_automation =============================================
# 2024-02-16 16:07:02,762 - INFO - START web_automation Start Time = 2024-02-16 16:07:02
# 2024-02-16 16:07:02,762 - INFO - web_automation Step 0 - Initialize the configuration file parser
# 2024-02-16 16:07:02,878 - INFO - Imported existing <module 'comtypes.gen' from 'C:\\Users\\josep\\anaconda3\\lib\\site-packages\\comtypes\\gen\\__init__.py'>
# 2024-02-16 16:07:02,878 - INFO - Using writeable comtypes cache directory: 'C:\Users\josep\anaconda3\lib\site-packages\comtypes\gen'
# 2024-02-16 16:07:57,834 - INFO - PERFORMANCE web_automation The total process duration was:55.07
# 2024-02-16 16:07:57,834 - INFO - PERFORMANCE web_automation Stop Time = 2024-02-16 16:07:57
# 2024-02-16 16:07:57,835 - INFO - PERFORMANCE web_automation Low process duration less than 3 minutes:55.07
# 2024-02-16 16:07:57,835 - INFO - PERFORMANCE web_automation Performance optimization is optional
# ...
